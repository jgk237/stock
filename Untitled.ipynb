# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('bq-results-20230414-205924-1681505974800.csv')
df2=pd.read_csv('bq-results-20230414-210045-1681506054580.csv')
df3=pd.read_csv('bq-results-20230414-210330-1681506224804.csv')
df4=pd.read_csv('bq-results-20230414-210455-1681506313730.csv')
df5=pd.read_csv('bq-results-20230414-210630-1681506404411.csv')
df6=pd.read_csv('bq-results-20230414-210836-1681506532204.csv')
df7=pd.read_csv('bq-results-20230414-214948-1681509023746.csv')

# %%
df8=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis='rows')

# %%
df8.shape
# Out:
# (59955920, 4)

# %%
df8.isnull().sum()
# Out:
# ds          0
# symbol    191
# close       0
# volume      0
# dtype: int64

# %%
df8.dropna()
# Out:
#                   ds   symbol      close     volume
# 0         1992-02-28      AFL   2.000000   609000.0
# 1         1992-02-03      WDC   2.000000   250200.0
# 2         1992-02-03     FACO   2.000000    18600.0
# 3         1992-02-21     FICO   2.000000   783000.0
# 4         1992-02-03    MOG-A   2.000000     2363.0
# ...              ...      ...        ...        ...
# 12741492  2020-07-30  0329.HK   0.580000  1168000.0
# 12741493  2020-07-30     NYMX   3.180000    76258.0
# 12741494  2020-07-31    GDNSF   0.592500    84857.0
# 12741495  2020-07-31     MUEL  26.145648      550.0
# 12741496  2020-07-31     CYDY   4.974000  8231596.0
#
# [59955729 rows x 4 columns]

# %%
df=pd.concat([df6,df7])
df
# Out:
#                   ds    symbol      close    volume
# 0         2016-03-11  HYDRA.AS  33.009998       345
# 1         2016-03-11      SMLR   1.530000     16658
# 2         2016-03-14       CVA  16.520000   1075159
# 3         2016-03-14      NFLX  98.130000  11251874
# 4         2016-03-15   2882.HK   4.760000      4200
# ...              ...       ...        ...       ...
# 12741492  2020-07-30   0329.HK   0.580000   1168000
# 12741493  2020-07-30      NYMX   3.180000     76258
# 12741494  2020-07-31     GDNSF   0.592500     84857
# 12741495  2020-07-31      MUEL  26.145648       550
# 12741496  2020-07-31      CYDY   4.974000   8231596
#
# [28028871 rows x 4 columns]

# %%
df8
# Out:
#            ds symbol  close    volume
# 0  1992-02-28    AFL  2.000  609000.0
# 1  1992-02-03    WDC  2.000  250200.0
# 2  1992-02-03   FACO  2.000   18600.0
# 3  1992-02-21   FICO  2.000  783000.0
# 4  1992-02-03  MOG-A  2.000    2363.0
# 5  1992-02-28  VLGEA  2.000    6400.0
# 6  1992-02-13  VLGEA  2.000    4000.0
# 7  1992-02-07    MSB  2.125   55800.0
# 8  1992-02-05   PFIN  2.125    1000.0
# 9  1992-02-27   RAMP  2.125   25600.0

# %%
company_names=df8['symbol'].unique().tolist()

# %%
company_names[:10]
# Out:
# ['AFL', 'WDC', 'FACO', 'FICO', 'MOG-A', 'VLGEA', 'MSB', 'PFIN', 'RAMP', 'BDN']

# %%
df8['ds']=pd.to_datetime(df8['ds'])

# %%
df8=df8.sort_values(by='ds')
df8
# Out:
#                  ds   symbol        close     volume
# 947673   1990-01-01   GFRD.L    50.843601        0.0
# 830101   1990-01-01    TLW.L    13.157500        0.0
# 1789036  1990-01-01    FSJ.L   109.655098        0.0
# 830114   1990-01-01   DWHT.L    43.333302        0.0
# 1812495  1990-01-01    N4P.L  1200.000000        0.0
# ...             ...      ...          ...        ...
# 2706864  2023-04-13   GABI.L    73.550003   267679.0
# 7681442  2023-04-13  0270.HK     7.850000  3029028.0
# 7681443  2023-04-13     WEYS    25.810000     4567.0
# 7681445  2023-04-13      FPL     6.170000    25498.0
# 3530801  2023-04-13      SKE     7.090000    68640.0
#
# [59955920 rows x 4 columns]

# %%
afl_df=df8[df8['symbol']=='AFL']
afl_df=afl_df.sort_values(by='ds')
afl_df
# Out:
#                 ds symbol      close     volume
# 547835  1990-01-02    AFL   1.175000   966000.0
# 475184  1990-01-03    AFL   1.150000  3040500.0
# 474618  1990-01-04    AFL   1.125000  2995500.0
# 185013  1990-01-05    AFL   1.125000   859500.0
# 1361000 1990-01-08    AFL   1.141667  1906500.0
# ...            ...    ...        ...        ...
# 1157749 2023-04-06    AFL  64.560000  2354566.0
# 8145107 2023-04-10    AFL  64.970000  1784893.0
# 299898  2023-04-11    AFL  65.710000  1839201.0
# 4607758 2023-04-12    AFL  65.980000  2253512.0
# 4607749 2023-04-13    AFL  66.300000  2603091.0
#
# [8385 rows x 4 columns]

# %%
afl_df.isnull().sum()
# Out:
# ds        0
# symbol    0
# close     0
# volume    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(afl_df['ds'],afl_df['close'])

# %%
import sys
# !{sys.executable} -m pip install chart-studio
# Out:
# ...
#      ---------------------------------------- 64.4/64.4 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import plot

from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12741497 entries, 0 to 12741496
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   ds      datetime64[ns]
#  1   symbol  object
#  2   close   float64
#  3   volume  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 388.8+ MB

# %%
layout=go.Layout(
    title='Stock Prices of AFL',
    xaxis=dict(
        title='Date',
        titlefont=dict(
            family='Courier New,monospace',
            size=18,
            color='#7f7f7f'
            
            
        )
    ),
    yaxis=dict(
        title='Price',
        titlefont=dict(
            family='Courier New,monospace',
            size=18,
            color='#7f7f7f'
            
            
        )
    )
)
afl_df_data=[{'x':afl_df['ds'],'y':afl_df['close']}]
plot=go.Figure(data=afl_df_data,layout=layout)

# %%
iplot(plot)
# Out:
# <div>                            <div id="f509396e-b57e-4654-bdc5-3bcda957ce02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f509396e-b57e-4654-bdc5-3bcda957ce02")) {                    Plotly.newPlot(                        "f509396e-b57e-4654-bdc5-3bcda957ce02",                        [{"x":["1990-01-02T00:00:00","1990-01-03T00:00:00","1990-01-04T00:00:00","1990-01-05T00:00:00","1990-01-08T00:00:00","1990-01-09T00:00:00","1990-01-10T00:00:00","1990-01-11T00:00:00","1990-01-12T00:00:00","1990-01-15T00:00:00","1990-01-16T00:00:00","1990-01-17T00:00:00","1990-01-18T00:00:00","1990-01-19T00:00:00","1990-01-22T00:00:00","1990-01-23T00:00:00","1990-01-24T00:00:00","1990-01-25T00:00:00","1990-01-26T00:00:00","1990-01-29T00:00:00","1990-01-30T00:00:00"
# ...

# %%
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler,StandardScaler

from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# %%
afl_df2=afl_df.drop('ds',axis='columns')

# %%
afl_df2
# Out:
#         symbol      close     volume
# 547835     AFL   1.175000   966000.0
# 475184     AFL   1.150000  3040500.0
# 474618     AFL   1.125000  2995500.0
# 185013     AFL   1.125000   859500.0
# 1361000    AFL   1.141667  1906500.0
# ...        ...        ...        ...
# 1157749    AFL  64.560000  2354566.0
# 8145107    AFL  64.970000  1784893.0
# 299898     AFL  65.710000  1839201.0
# 4607758    AFL  65.980000  2253512.0
# 4607749    AFL  66.300000  2603091.0
#
# [8385 rows x 3 columns]

# %%
ma100=afl_df2.close.rolling(100).mean()
ma100
# Out:
# 547835         NaN
# 475184         NaN
# 474618         NaN
# 185013         NaN
# 1361000        NaN
#             ...
# 1157749    69.1466
# 8145107    69.0933
# 299898     69.0633
# 4607758    69.0208
# 4607749    68.9757
# Name: close, Length: 8385, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(afl_df['ds'][-1000:],afl_df.close[-1000:])
plt.plot(afl_df['ds'][-1000:],ma100[-1000:])

# %%
ma200=afl_df2.close.rolling(200).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(afl_df['ds'][-1000:],afl_df.close[-1000:])
plt.plot(afl_df['ds'][-1000:],ma100[-1000:])
plt.plot(afl_df['ds'][-1000:],ma200[-1000:],'r')

# %%
plt.figure(figsize=(12,6))
plt.plot(afl_df['ds'][-1000:],afl_df.close[-1000:])
plt.plot(afl_df['ds'][-1000:],ma100[-1000:])
plt.plot(afl_df['ds'][-1000:],ma200[-1000:],'r')
plt.plot(afl_df['ds'][-1000:],afl_df2['volume'][-1000:]*60)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
afl_df2['volume']=scaler.fit_transform(np.array(afl_df2['volume']).reshape(-1,1))

# %%
data_training=pd.DataFrame(afl_df2['close'][0:int(len(afl_df)*0.7)])
data_testing=pd.DataFrame(afl_df2['close'][int(len(afl_df)*0.7):int(len(afl_df2))])

# %%
data_training.head()
# Out:
#             close
# 547835   1.175000
# 475184   1.150000
# 474618   1.125000
# 185013   1.125000
# 1361000  1.141667

# %%
data_training_array=scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.01026746],
#        [0.00951619],
#        [0.00876491],
#        ...,
#        [0.72788741],
#        [0.71075829],
#        [0.72938997]])

# %%
X_train=[]
y_train=[]
for i in range(100,data_training_array.shape[0]):
    X_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])
len(x_train)
# Out:
# 8285

# %%
X_train,y_train=np.array(X_train),np.array(y_train)
X_train.shape
# Out:
# (5769, 100, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
# !{sys.executable} -m pip install keras
# !{sys.executable} -m pip install tensorflow
# Out:
# ^C
# ...

# %%
from  keras.layers import Dense,Dropout,LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_8 (LSTM)               (None, 100, 50)           10400
#
#  dropout_8 (Dropout)         (None, 100, 50)           0
#
#  lstm_9 (LSTM)               (None, 100, 60)           26640
#
#  dropout_9 (Dropout)         (None, 100, 60)           0
#
#  lstm_10 (LSTM)              (None, 100, 80)           45120
#
#  dropout_10 (Dropout)        (None, 100, 80)           0
#
#  lstm_11 (LSTM)              (None, 120)               96480
#
#  dropout_11 (Dropout)        (None, 120)               0
#
#  dense_2 (Dense)             (None, 1)                 121
#
# ...
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=35)
# Out:
# Epoch 1/35
# 181/181 [==============================] - 43s 207ms/step - loss: 0.0157
# Epoch 2/35
# 181/181 [==============================] - 47s 260ms/step - loss: 0.0052
# Epoch 3/35
# 181/181 [==============================] - 82s 454ms/step - loss: 0.0046
# Epoch 4/35
# 181/181 [==============================] - 81s 445ms/step - loss: 0.0045
# Epoch 5/35
# 181/181 [==============================] - 79s 438ms/step - loss: 0.0037
# Epoch 6/35
# 181/181 [==============================] - 79s 437ms/step - loss: 0.0035
# Epoch 7/35
# 181/181 [==============================] - 78s 429ms/step - loss: 0.0034
# Epoch 8/35
# 181/181 [==============================] - 80s 440ms/step - loss: 0.0030
# Epoch 9/35
# 181/181 [==============================] - 79s 435ms/step - loss: 0.0029
# Epoch 10/35
# 181/181 [==============================] - 79s 439ms/step - loss: 0.0027
# Epoch 11/35
# 181/181 [==============================] - 80s 443ms/step - loss: 0.0026
# Epoch 12/35
# ...

# %%
model.save('model.h5')

# %%
data_testing.shape
# Out:
# (2516, 1)

# %%
past_100_days=data_training.tail(100)
past_100_days
# Out:
#            close
# 3046055   25.480
# 1876403   25.615
# 8457863   25.945
# 9171792   25.925
# 10799604  25.755
# ...          ...
# 9724627   25.105
# 5389569   24.905
# 2533092   25.055
# 11526942  24.485
# 4812662   25.105
#
# [100 rows x 1 columns]

# %%
final_df=pd.concat([past_100_days,data_testing],ignore_index=True)

# %%
final_df
# Out:
#        close
# 0     25.480
# 1     25.615
# 2     25.945
# 3     25.925
# 4     25.755
# ...      ...
# 2611  64.560
# 2612  64.970
# 2613  65.710
# 2614  65.980
# 2615  66.300
#
# [2616 rows x 1 columns]

# %%
input_data=scaler.fit_transform(final_df)

# %%
input_data.shape
# Out:
# (2616, 1)

# %%
X_test=[]
y_test=[]

for i in range(100,input_data.shape[0]):
    X_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

# %%
X_test,y_test=np.array(X_test),np.array(y_test)

# %%
y_predicted=model.predict(X_test)
# Out:
# 79/79 [==============================] - 11s 101ms/step

# %%
y_predicted.shape
# Out:
# (2516, 1)

# %%
y_test
# Out:
# array([0.00514995, 0.00252449, 0.00747248, ..., 0.83580733, 0.84126022,
#        0.84772291])

# %%
scaler.scale_
# Out:
# array([0.0201959])

# %%
scale_factor=1/0.0201959
y_predicted=y_predicted*scale_factor
y_test=y_test*scale_factor

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Time')
plt.ylabel('Price')
plt.plot(y_test[-500:],label="Stock Price")
plt.plot(y_predicted[-500:],'r',label='Predicted Price')
plt.legend()
